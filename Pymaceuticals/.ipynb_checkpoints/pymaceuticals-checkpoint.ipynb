# %% [markdown]
# # Pymaceuticals Inc.
# ---
# ### Over the course of 45 days, tumor development was observed and measured. The purpose of this study is to compare the performance of Pymaceuticals’ drug of interest, Capomulin, against the other treatment regimens.
#
# * Capomulin and Ramicane both performed very favorably against Infubinol and Ceftamin when measuring final tumor volumes. Infubinol and Ceftamin both had higher quartiles overall, indicating less effectiveness. Infubinol performed the poorest of the four, despite it having the only possible outlier of the group (which was in a favorable low-value direction).
# * The results of Capomulin and Ramicane were somewhat similar when comparing the final tumor volumes. Both drugs appeared effective and resulted in similar final tumor size. Capomulin's results are skewed upward, showing a higher median value than the more evenly-balanced Ramicane results. This is slightly negative for Capomulin because it indicates that Capomulin has a greater number of larger tumors within it's distribution when compared to Ramicane. This is likely a small difference but a more in-depth analysis of the results would be needed to reveal the specifics of both distributions.
# * There is a strong positive correlation (0.84) between the weight of the mouse and the average ending volume of the tumors with Capomulin. This indicates that while larger mice will have larger tumors, tumor volume decreases with Capomulin remain proportionate to the subject body weight. In other words, it shows a similar effectiveness across all subject body sizes.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_study_main_df = pd.merge(study_results, mouse_metadata, on='Mouse ID', how='left')

# Display the data table for preview
mouse_study_main_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
print(f"Unique IDs: {len(mouse_study_main_df['Mouse ID'].unique())}")
# Out:
# Unique IDs: 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
dup_ids = mouse_study_main_df.loc[mouse_study_main_df.duplicated(subset=['Mouse ID', 'Timepoint']), 'Mouse ID'].unique()
dup_ids
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID.
for id in dup_ids:
    dup_list_df = mouse_study_main_df[mouse_study_main_df['Mouse ID'] == id]
dup_list_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
mouse_study_clean_df = mouse_study_main_df[mouse_study_main_df['Mouse ID'].isin(dup_ids) == False]
mouse_study_clean_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
print(f"ID count with duplicates removed: {len(mouse_study_clean_df['Mouse ID'].unique())}")
# Out:
# ID count with duplicates removed: 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
study_mean = mouse_study_clean_df.groupby('Drug Regimen').mean()['Tumor Volume (mm3)']
study_median = mouse_study_clean_df.groupby('Drug Regimen').median()['Tumor Volume (mm3)']
study_var = mouse_study_clean_df.groupby('Drug Regimen').var()['Tumor Volume (mm3)']
study_std = mouse_study_clean_df.groupby('Drug Regimen').std()['Tumor Volume (mm3)']
study_sem = mouse_study_clean_df.groupby('Drug Regimen').sem()['Tumor Volume (mm3)']
summary_stats_df = pd.DataFrame({
    'Mean Tumor Volume': study_mean,
    'Median Tumor Volume': study_median,
    'Tumor Volume Variance': study_var,
    'Tumor Volume Std. Dev.': study_std,
    'Tumor Volume Std. Err.': study_sem
})
summary_stats_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line.
summary_agg_df = mouse_study_clean_df.groupby('Drug Regimen').agg({'Tumor Volume (mm3)':['mean','median','var','std','sem']})
summary_agg_df
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
num_mice_tested = mouse_study_clean_df['Drug Regimen'].value_counts()
num_mice_tested.plot(kind='bar')
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Mice Tested')
plt.show()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
num_mice_tested = mouse_study_clean_df["Drug Regimen"].value_counts()
plt.bar(num_mice_tested.index.values, num_mice_tested.values)
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Mice Tested')
plt.xticks(rotation=90)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
sex_of_mice = mouse_study_clean_df["Sex"].value_counts()
sex_of_mice.plot(kind='pie', autopct="%1.1f%%")
# Out:
# <AxesSubplot:ylabel='Sex'>

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
sex_of_mice = mouse_study_clean_df["Sex"].value_counts()
plt.pie(sex_of_mice.values, labels=sex_of_mice.index.values, autopct='%1.1f%%')
plt.ylabel("Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
max_timepoint_df = mouse_study_clean_df.groupby(['Mouse ID'])['Timepoint'].max()
max_timepoint_df.reset_index()
                                                
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
merged_tumor_vol_df = pd.merge(max_timepoint_df, mouse_study_clean_df, on=["Mouse ID", "Timepoint"], how='left')
merged_tumor_vol_df
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419                 2    Infubinol
# 1       a251         45           65.525743                 1    Infubinol
# 2       a262         45           70.717621                 4      Placebo
# 3       a275         45           62.999356                 3     Ceftamin
# 4       a366         30           63.440686                 1     Stelasyn
# ..       ...        ...                 ...               ...          ...
# 243     z435         10           48.710661                 0     Propriva
# 244     z578         45           30.638696                 0     Ramicane
# 245     z581         45           62.754451                 3    Infubinol
# 246     z795         45           65.741070                 3     Naftisol
# 247     z969         45           73.867845                 4     Naftisol
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatment_list = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
# treatment_list = ['Capomulin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_list = []

# Calculate the IQR and quantitatively determine if there are any potential outliers.
for treatment in treatment_list:

    # Locate the rows which contain mice on each drug and get the tumor volumes
    tumor_vol_output = merged_tumor_vol_df.loc[merged_tumor_vol_df['Drug Regimen'] == treatment, 'Tumor Volume (mm3)']
    
    # add subset 
    tumor_vol_list.append(tumor_vol_output)
    
    # Determine outliers using upper and lower bounds
    quartiles = tumor_vol_output.quantile([.25,.5,.75])
    lowerq = quartiles[.25]
    upperq = quartiles[.75]
    irq = upperq - lowerq
    lower_bound = lowerq - (1.5*irq)
    upper_bound = upperq + (1.5*irq)
    outliers = tumor_vol_output.loc[(tumor_vol_output < lower_bound) | (tumor_vol_output > upper_bound)]
    print(f'Outlier drug regimen: {treatment}, possible outlier: {outliers}')
# Out:
# Outlier drug regimen: Capomulin, possible outlier: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Outlier drug regimen: Ramicane, possible outlier: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Outlier drug regimen: Infubinol, possible outlier: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Outlier drug regimen: Ceftamin, possible outlier: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
plt.boxplot(tumor_vol_list, labels=treatment_list, flierprops=dict(markerfacecolor='red'))
plt.ylabel('Final Tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
capomulin_line_data = mouse_study_clean_df[mouse_study_clean_df['Drug Regimen'] == 'Capomulin']
one_capomulin_mouse = capomulin_line_data[capomulin_line_data['Mouse ID'] == 'l509']
plt.plot(one_capomulin_mouse['Timepoint'], one_capomulin_mouse['Tumor Volume (mm3)'])
plt.title('Capomulin treatment of Mouse L509')
plt.xlabel('')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capomulin_scatter_data = mouse_study_clean_df[mouse_study_clean_df['Drug Regimen'] == 'Capomulin']
capomulin_mean = capomulin_scatter_data.groupby(['Mouse ID']).mean()
x_values = capomulin_mean['Weight (g)']
y_values = capomulin_mean['Tumor Volume (mm3)']
plt.scatter(x_values, y_values)
plt.xlabel('Average Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
from scipy.stats import linregress
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between average volume and weight is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Average Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.show()
# Out:
# The correlation between average volume and weight is 0.84
